# %%
print("hello")
# Out:
# hello

# %%
# Creating a list with different data types
my_list = ["apple", 42, 3.14, True]

# Accessing items 
print(my_list[0])  
print(my_list[-1])

# Slicing 
print(my_list[1:3]) # Output: [42, 3.14]
# Out:
# apple
# True
# [42, 3.14]

# %%
for i in range(1, 51):
    if i % 3 == 0 and i % 5 == 0:
        print("FizzBuzz")
    elif i % 3 == 0:
        print("Fizz")
    elif i % 5 == 0:
        print("Buzz")
    else:
        print(i)
# Out:
# 1
# 2
# Fizz
# 4
# Buzz
# Fizz
# 7
# 8
# Fizz
# Buzz
# 11
# Fizz
# 13
# 14
# FizzBuzz
# 16
# 17
# Fizz
# 19
# Buzz
# Fizz
# 22
# 23
# Fizz
# Buzz
# 26
# Fizz
# 28
# 29
# FizzBuzz
# 31
# 32
# Fizz
# 34
# Buzz
# Fizz
# 37
# 38
# Fizz
# Buzz
# 41
# Fizz
# 43
# 44
# FizzBuzz
# 46
# 47
# Fizz
# 49
# Buzz

# %%
print("hello wprl")
# Out:
# hello wprl

# %%
print("Anshul Sonkar")
# Out:
# Anshul Sonkar

# %%
print("Anshul Sonkar")
# Out:
# Anshul Sonkar

# %%
for i in range(1, 51):
    if i % 3 == 0 and i % 5 == 0:
        print("FizzBuzz")
    elif i % 3 == 0:
        print("Fizz")
    elif i % 5 == 0:
        print("Buzz")
    else:
        print(i)
# Out:
# 1
# 2
# Fizz
# 4
# Buzz
# Fizz
# 7
# 8
# Fizz
# Buzz
# 11
# Fizz
# 13
# 14
# FizzBuzz
# 16
# 17
# Fizz
# 19
# Buzz
# Fizz
# 22
# 23
# Fizz
# Buzz
# 26
# Fizz
# 28
# 29
# FizzBuzz
# 31
# 32
# Fizz
# 34
# Buzz
# Fizz
# 37
# 38
# Fizz
# Buzz
# 41
# Fizz
# 43
# 44
# FizzBuzz
# 46
# 47
# Fizz
# 49
# Buzz

# %%
#list with different data types
my_list = ["apple", 42, 3.14, True]

# Accessing items 
print(my_list[0])  
print(my_list[-1])

# Slicing 
print(my_list[1:3])
# Out:
# apple
# True
# [42, 3.14]

# %%
lst=[7,-4,-2,9,0,11,17,8,19,10]
print(lst[:-5:10])
print([])

# %%
# Add elements 
st=[7, -4, -2, 9, 0, 11, 17, 8, 19, 10]
lst.append("hello")
lst.insert(-4,36)
lst1=[45,46,47]
lst.extend(lst)
lst+=lst1
print(lst)

# %%
list=[1,2,3,"hello",5,7]
print(list)
# Out:
# [1, 2, 3, 'hello', 5, 7]

# %%
list=[1,2,3,"hello",5,7]
# print(list)
for i in range(len(list)):
    print(list[i],end=" ")
# Out:
# 1 2 3 hello 5 7

# %%
lst=[[1,2,3,5,6],[3,4,5],[3,5,7],[10,20,30]]
#  ans = [15,12,15,60]
ans=[]
for i in range(len(lst)):
    temp=0
    for j in lst[i]:
        temp+=j
        ans.append(temp)

        
        print(ans)
# Out:
# [1]
# [1, 3]
# [1, 3, 6]
# [1, 3, 6, 11]
# [1, 3, 6, 11, 17]
# [1, 3, 6, 11, 17, 3]
# [1, 3, 6, 11, 17, 3, 7]
# [1, 3, 6, 11, 17, 3, 7, 12]
# [1, 3, 6, 11, 17, 3, 7, 12, 3]
# [1, 3, 6, 11, 17, 3, 7, 12, 3, 8]
# [1, 3, 6, 11, 17, 3, 7, 12, 3, 8, 15]
# [1, 3, 6, 11, 17, 3, 7, 12, 3, 8, 15, 10]
# [1, 3, 6, 11, 17, 3, 7, 12, 3, 8, 15, 10, 30]
# [1, 3, 6, 11, 17, 3, 7, 12, 3, 8, 15, 10, 30, 60]

# %%
lst=[[3,2,1,8],[50,3,7,9],[2,3,7,8]]
# 
ans=[]
for i in range(len(lst)):
    temp=lst[i].copy()
    if i%2==0:
        for j in range(len(temp)):
            if temp[j]%2!=0:
                temp[j]+=1
                ans.append(temp)

            else:
                for j in range(len(lst)):
                    if temp[j]%2!=0:
                        temp[j]+=1
                        ans.append(temp)
                        print(lst)
                        print(ans)
# Out:
# [[3, 2, 1, 8], [50, 3, 7, 9], [2, 3, 7, 8]]
# [[4, 2, 2, 8], [4, 2, 2, 8]]
# [[3, 2, 1, 8], [50, 3, 7, 9], [2, 3, 7, 8]]
# [[4, 2, 2, 8], [4, 2, 2, 8], [2, 4, 7, 8]]
# [[3, 2, 1, 8], [50, 3, 7, 9], [2, 3, 7, 8]]
# [[4, 2, 2, 8], [4, 2, 2, 8], [2, 4, 8, 8], [2, 4, 8, 8]]

# %%
# Delete
lst=[1,3,5,12,14,15,23]
# del lst [4]
# print(lst)
# lst.pop(3)
# print(lst)
x=lst.pop(2)
print(x)
print(lst)
# Out:
# 5
# [1, 3, 12, 14, 15, 23]

# %%
lst= [1,3,5,12,14,15,3,23]
lst.count(3)
print(lst.index(14))
# Out:
# 4

# %%
lst=[1,3,5,12,14,15,3,23]
lst.clear()
print(lst)
# Out:
# []

# %%
lst=[1,3,5,12,14,15,3,23]
lst.reverse()
print(lst)
# Out:
# [23, 3, 15, 14, 12, 5, 3, 1]

# %%
lst=[1,3,5,12,14,15,3,23]
lst1=sorted(lst,reverse=True)
# lst.sort()
# lst1=sorted(lst)
print(lst)
print(lst1)
# Out:
# [1, 3, 5, 12, 14, 15, 3, 23]
# [23, 15, 14, 12, 5, 3, 3, 1]

# %%
lst = [1, 2, 3]

while lst:
    lst.pop()
    
print(lst)
# Out:
# []

# %%
lst = [1, 2, 3, 4]

new_lst = [x*x for x in lst]
print(new_lst)
# Out:
# [1, 4, 9, 16]

# %%
color1=["red","black","pink","yellow"]
color2=["orange","green","pink","red"]
lst1=[]
lst2=[]
for i in color1:
    if i not in color2:
        lst1.append(i)
for i in color2:
    if i not in color1:
        lst2.append(i)
print(lst1)
print(lst2)
# Out:
# ['black', 'yellow']
# ['orange', 'green']

# %%
lst=[2,2,3,4,4,6,5,5,5,7,7,6,6,0,0,9,9]
lst1=[]

temp = [lst[0]]
for i in range(1, len(lst)):
    if lst[i-1] == lst[i]:
       temp.append(lst[i])
    else:
        lst1.append(temp)
        temp = [lst[i]]

lst1.append(temp)

print(lst1)
# Out:
# [[2, 2], [3], [4, 4], [6], [5, 5, 5], [7, 7], [6, 6], [0, 0], [9, 9]]

# %%
world_list=['hello','user','i','am','learning','python']
temp = ' # '.join(world_list)
print(temp)
# Out:
# hello # user # i # am # learning # python

# %%
lst=[2,2,3,4,4,6,5,5,5,7,7,6,6,0,0,9,9]
lst1=[0]
for i in lst:
    if lst1[-1]!=i:
         lst1.append(i)
print(lst1)
# Out:
# [0, 2, 3, 4, 6, 5, 7, 6, 0, 9]

# %%
x="hello,everyone.lets,learn,python."
y=x.replace(',','?')
r=y.replace('.',',')
z=r.replace('?','.')

print(z)
# Out:
# hello.everyone,lets.learn.python,

# %%
x="hello,everyone.lets,learn,python."
y=x.replace(',','?')
r=y.replace('.',',')
z=r.replace('?','.')

print(z)
# Out:
# hello.everyone,lets.learn.python,

# %%
x="hello,everyone.lets,learn,python."
y=x.replace(',','?')
r=y.replace('.',',')
z=r.replace('?','.')

print(x)
print(y)
print(z)
# Out:
# hello,everyone.lets,learn,python.
# hello?everyone.lets?learn?python.
# hello.everyone,lets.learn.python,

# %%
x = "apple banana apple"

y = x.replace("apple", "mango")

print(x)
print(y)
# Out:
# apple banana apple
# mango banana mango

# %%
x = "a,b.c,d"

z = x.replace(",", "#").replace(".", ",").replace("#", ".")

print(z)
# Out:
# a.b,c.d

# %%
x = "hello everyone"

print(x.count("e"))
# Out:
# 4

# %%
x = "Hello World"

print(x.upper())
print(x.lower())
# Out:
# HELLO WORLD
# hello world

# %%
x = "   python   "

print(x.strip())
# Out:
# python

# %%
lst = ["python", "java", "c++"]

x = "-".join(lst)

print(x)
# Out:
# python-java-c++

# %%
s=set()
s1={}
print(type(s1))
# Out:
# <class 'dict'>

# %%
s={1,2,3,"hello"}
print(s)
# Out:
# {'hello', 2, 3, 1}

# %%
lst = [1, 2, 4, 5]

n = 5

total = n * (n + 1) // 2
print(total - sum(lst))
# Out:
# 3

# %%
lst = [0, 1, 0, 3, 12]

new_lst = []

for i in lst:
    if i != 0:
        new_lst.append(i)

for i in range(lst.count(0)):
    new_lst.append(0)

print(new_lst)
# Out:
# [1, 3, 12, 0, 0]
